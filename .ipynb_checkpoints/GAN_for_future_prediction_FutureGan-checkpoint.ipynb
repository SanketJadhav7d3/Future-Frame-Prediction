#   inflating: /content/dataset/person24_walking_d3_uncomp.avi
#   inflating: /content/dataset/person24_walking_d4_uncomp.avi
#   inflating: /content/dataset/person25_walking_d1_uncomp.avi
#   inflating: /content/dataset/person25_walking_d2_uncomp.avi
#   inflating: /content/dataset/person25_walking_d3_uncomp.avi
#   inflating: /content/dataset/person25_walking_d4_uncomp.avi

# %%
# !pip install av
# Out:
# Collecting av
#   Downloading av-12.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Downloading av-12.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 10.9 MB/s eta 0:00:00
# Installing collected packages: av
# Successfully installed av-12.3.0

# %%
import os

import pandas as pd

import torch
import torchvision
from torchvision.io import read_video
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
train_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

# %%
def split_video(video_tensor):
  # frames X height X width X channel
  frames, height, width, channel = video_tensor.shape
  total_segs = frames // 12
  slices = torch.reshape(video_tensor[:total_segs*12], (total_segs, 12, height, width, channel))
  return slices

# %%
video, audio, info = torchvision.io.read_video('/content/dataset/person01_walking_d1_uncomp.avi')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/video.py:161: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")

# %%
slices = split_video(video)
one_slice = slices[0]

slices.shape, one_slice.shape
# Out:
# (torch.Size([46, 12, 120, 160, 3]), torch.Size([12, 120, 160, 3]))

# %%
plt.figure(figsize=(15, 3))

for i in range(12):
  plt.subplot(1, 12, i + 1)
  plt.imshow(one_slice[i])
  plt.axis('off')

# %%
# rough code

meta_data = pd.DataFrame({
  'file path': [],
  'total frames': [],
  'total slices': []
})

file_paths = []
total_frames = []
total_slices = []

for file_name in os.listdir('/content/dataset'):
  file_path = os.path.join('/content/dataset', file_name)
  video, audio, info = read_video(file_path)
  file_paths.append(file_path)
  total_frames.append(video.shape[0])
  total_slices.append(video.shape[0] // 12)

meta_data['file path'] = file_paths
meta_data['total frames'] = total_frames
meta_data['total slices'] = total_slices

# %%
meta_data['total frames'].sum()
# Out:
# 65795

# %%
# index to slice mapping

idx_to_slices = pd.DataFrame({
  'global idx': [], # global idx i.e. considering all videos
  'file path': [],
  'local idx': []   # to get the local slice number to the video
})

last_index = 0
for idx, row in meta_data.iterrows():
  total_slice = row['total slices']
  file_path = row['file path']
  indexes = [int(i) for i in range(last_index, last_index+total_slice)]
  local_indexes = list(range(0, total_slice))
  last_index = last_index+total_slice
  idx_to_slices = pd.concat([idx_to_slices, pd.DataFrame({'global idx': indexes, 'file path': [file_path] * len(indexes),
                                                          'local idx': local_indexes})])
idx_to_slices.set_index(['global idx'], inplace=True)

# %%
idx_to_slices
# Out:
#                                                   file path  local idx
# global idx
# 0.0         /content/dataset/person24_walking_d4_uncomp.avi        0.0
# 1.0         /content/dataset/person24_walking_d4_uncomp.avi        1.0
# 2.0         /content/dataset/person24_walking_d4_uncomp.avi        2.0
# 3.0         /content/dataset/person24_walking_d4_uncomp.avi        3.0
# 4.0         /content/dataset/person24_walking_d4_uncomp.avi        4.0
# ...                                                     ...        ...
# 5438.0      /content/dataset/person05_walking_d2_uncomp.avi       51.0
# 5439.0      /content/dataset/person05_walking_d2_uncomp.avi       52.0
# 5440.0      /content/dataset/person05_walking_d2_uncomp.avi       53.0
# 5441.0      /content/dataset/person05_walking_d2_uncomp.avi       54.0
# 5442.0      /content/dataset/person05_walking_d2_uncomp.avi       55.0
#
# [5443 rows x 2 columns]

# %%
idx_to_slices.to_csv('idx_to_slices.csv', index=False)

# %%
class HumanMotionDataset(Dataset):
  def __init__(self, data_csv, transform=None, is_val=False):
    self.data_csv = data_csv
    self.transform = transform
    self.is_val = is_val

  def __len__(self):
    return self.data_csv.shape[0]

  def __getitem__(self, idx):
    file_path = self.data_csv.iloc[idx, 0]
    local_idx = int(self.data_csv.iloc[idx, 1])
    # read file
    video, audio, info = read_video(file_path)
    slices = split_video(video)
    slice_ = slices[local_idx]

    # change into the format frames * channels * height * width
    slice_ = slice_.permute(0, 3, 1, 2)

    if self.transform:
      slice_ = self.transform(slice_)

    return slice_[:6], slice_[6:]

# %%
dataset = HumanMotionDataset(idx_to_slices, train_transform)

# %%
input, output = dataset[5023]
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/video.py:161: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")

# %%
for i in range(6):
  plt.subplot(1, 6, i + 1)
  plt.imshow(input[i].permute(1, 2, 0).numpy())
  plt.axis('off')
plt.title("64x64 5 frames")
print(input.shape)
# Out:
# torch.Size([6, 3, 64, 64])

# %%
for i in range(6):
  plt.subplot(1, 6, i + 1)
  plt.imshow(output[i].permute(1, 2, 0).numpy())
  plt.axis('off')

plt.title("64x64 5 frames")
print(output.shape)
# Out:
# torch.Size([6, 3, 64, 64])

# %% [markdown]
# # Data Loader

# %%
train_dataloader = DataLoader(dataset, batch_size=12, shuffle=False)

# %%
inputs, outputs = next(iter(train_dataloader))

outputs.shape
# Out:
# torch.Size([12, 6, 3, 64, 64])

# %%
for i in range(6):
  plt.subplot(1, 6, i + 1)
  plt.imshow(outputs[11][i].permute(1, 2, 0).numpy())
  plt.axis('off')

plt.title("64x64 5 frames")
# Out:
# Text(0.5, 1.0, '64x64 5 frames')

# %%
def visualize_batch(batch):
  inputs, outputs = batch
  rows = 12
  cols = 12
  fig, axes = plt.subplots(rows, cols, figsize=(14, 14))

  for i in range(rows):
    for j in range(6):
      img = inputs[i][j].permute(1, 2, 0).numpy()
      axes[i, j].imshow(img)
      axes[i, j].axis('off')
    for j in range(6, 12) :
      img = outputs[i][j-6].permute(1, 2, 0).numpy()
      axes[i, j].imshow(img)
      axes[i, j].axis('off')

  fig.suptitle("One batch")

# %%
visualize_batch(next(iter(train_dataloader)))

# %% [markdown]
# # some experiments

# %%
inputs, outputs = next(iter(train_dataloader))
input = inputs[0]

conv_3d_layer = nn.Conv3d(
    in_channels=3,
    out_channels=256,
    kernel_size=(1, 1, 1),
    stride=(1, 1, 1),
)

input = input.unsqueeze(0)
input = input.permute(0, 2, 1, 3, 4)

# first dim = batch size
# second dim = channel of single input plane
# third dim = number of input planes
# fourth dim = height
# fifth dim = width
input.shape
# Out:
# torch.Size([1, 3, 6, 64, 64])

# %%
# first dim : batch size
# second dim : channels (number of kernels used)
# third dim : depth (convolution across depth)
# fourth dim : height (convolutional across height)
# fifth dim : width (convolutional across width duh)

conv_3d_layer(input.float()).shape
# Out:
# torch.Size([1, 256, 6, 64, 64])

# %% [markdown]
# # Model
#
# # Generator

# %%
def conv_3d_block(parameters):
  return nn.Sequential(
    nn.Conv3d(
      in_channels=parameters['in'],
      out_channels=parameters['out'],
      kernel_size=parameters['kernel'],
      stride=parameters['stride'],
      padding=parameters['padding']
    ),
    # weight   (yet to be added)
    nn.LeakyReLU(0.2),
    # Feature Normalization (yet to be added)
  )

def up_conv_3d_block(parameters):
  return nn.Sequential(
    nn.ConvTranspose3d(
      in_channels=parameters['in'],
      out_channels=parameters['out'],
      kernel_size=parameters['kernel'],
      stride=parameters['stride'],
      padding=parameters['padding']
    ),
    # weight scaling (yet to be added)
    nn.LeakyReLU(0.2),
    # Feature Normalization (yet to be added)
  )

class Generator(nn.Module):

  def __init__(self):
    super(Generator, self).__init__()

    # Encoder

    self.layers = {
      'down_conv_layers': {
          0: {
            'in': 3,
            'out': 256,
            'kernel': (1, 1, 1),
            'stride': (1, 1, 1),
            'padding': (0, 0, 0)
          },
          1: {
            'in': 256,
            'out': 256,
            'kernel': (3, 3, 3),
            'stride': (1, 1, 1),
            'padding': (1, 1, 1)
          },
          2: {
            'in': 256,
            'out': 512,
            'kernel': (1, 2, 2),
            'stride': (1, 2, 2),
            'padding': (0, 0, 0)
          },
          3: {
            'in': 512,
            'out': 512,
            'kernel': (3, 3, 3),
            'stride': (1, 1, 1),
            'padding': (1, 1, 1)
          },
          4: {
            'in': 512,
            'out': 512,
            'kernel': (1, 2, 2),
            'stride': (1, 2, 2),
            'padding': (0, 0, 0)
          },
          5: {
            'in': 512,
            'out': 512,
            'kernel': (3, 3, 3),
            'stride': (1, 1, 1),
            'padding': (1, 1, 1)
          },
          6: {
            'in': 512,
            'out': 512,
            'kernel': (1, 2, 2),
            'stride': (1, 2, 2),
            'padding': (0, 0, 0)
          },
          7: {
            'in': 512,
            'out': 512,
            'kernel': (3, 3, 3),
            'stride': (1, 1, 1),
            'padding': (1, 1, 1)
          },
          8: {
            'in': 512,
            'out': 512,
            'kernel': (1, 2, 2),
            'stride': (1, 2, 2),
            'padding': (0, 0, 0)
          },
          9: {
            'in': 512,
            'out': 512,
            'kernel': (3, 3, 3),
            'stride': (1, 1, 1),
            'padding': (1, 1, 1)
          },
          10: {
            'in': 512,
            'out': 512,
            'kernel': (6, 1, 1),
            'stride': (1, 1, 1),
            'padding': (0, 0, 0)
          }
      },
      'up_conv_layers': {
        0: {
          'in': 512,
          'out': 512,
          'kernel': (6, 1, 1),
          'stride': (1, 1, 1),
          'padding': (0, 0, 0),
          'down': False
        },
        1: {
          'in': 512,
          'out': 512,
          'kernel': (3, 3, 3),
          'stride': (1, 1, 1),
          'padding': (1, 1, 1),
          'down': True
        },
        2: {
          'in': 512,
          'out': 512,
          'kernel': (1, 2, 2),
          'stride': (1, 2, 2),
          'padding': (0, 0, 0),
          'down': False
        },
        3: {
          'in': 512,
          'out': 512,
          'kernel': (3, 3, 3),
          'stride': (1, 1, 1),
          'padding': (1, 1, 1),
          'down': True
        },
        4: {
          'in': 512,
          'out': 512,
          'kernel': (1, 2, 2),
          'stride': (1, 2, 2),
          'padding': (0, 0, 0),
          'down': False
        },
        5: {
          'in': 512,
          'out': 512,
          'kernel': (3, 3, 3),
          'stride': (1, 1, 1),
          'padding': (1, 1, 1),
          'down': True
        },
        6: {
          'in': 512,
          'out': 512,
          'kernel': (1, 2, 2),
          'stride': (1, 2, 2),
          'padding': (0, 0, 0),
          'down': False
        },
        7: {
          'in': 512,
          'out': 512,
          'kernel': (3, 3, 3),
          'stride': (1, 1, 1),
          'padding': (1, 1, 1),
          'down': True
        },
        8: {
          'in': 512,
          'out': 256,
          'kernel': (1, 2, 2),
          'stride': (1, 2, 2),
          'padding': (0, 0, 0),
          'down': False
        },
        9: {
          'in': 256,
          'out': 256,
          'kernel': (3, 3, 3),
          'stride': (1, 1, 1),
          'padding': (1, 1, 1),
          'down': True
        },
      }
    }
    self.encoder = nn.Sequential()

    for key, value in self.layers['down_conv_layers'].items():
      self.encoder.add_module("down_conv_"+str(key), nn.Sequential(
        conv_3d_block(value)
      ))

    # relu
    # decoder
    self.decoder = nn.Sequential()
    for key, value in self.layers['up_conv_layers'].items():
      if value['down']:
        self.decoder.add_module("down_conv_"+str(key), nn.Sequential(
          conv_3d_block(value)
        ))
      else:
        self.decoder.add_module("p_conv_"+str(key), nn.Sequential(
          up_conv_3d_block(value)
        ))
    # output
    self.output_layer =  nn.Conv3d(
        in_channels=256,
        out_channels=3,
        kernel_size=(1, 1, 1),
        stride=(1, 1, 1),
    )

  def forward(self, x):
    x = self.encoder(x)
    x = self.decoder(x)
    x = self.output_layer(x)
    return x

# %%
batch = next(iter(train_dataloader))

visualize_batch(batch)

# %%
inputs, outputs = batch

inputs.shape, outputs.shape
# Out:
# (torch.Size([12, 6, 3, 64, 64]), torch.Size([12, 6, 3, 64, 64]))

# %%
net_g = Generator()

net_g.encoder
# Out:
# Sequential(
#   (down_conv_0): Sequential(
#     (0): Sequential(
#       (0): Conv3d(3, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_1): Sequential(
#     (0): Sequential(
#       (0): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_2): Sequential(
#     (0): Sequential(
#       (0): Conv3d(256, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_3): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_4): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_5): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_6): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_7): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_8): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_9): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_10): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(6, 1, 1), stride=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
net_g.decoder
# Out:
# Sequential(
#   (p_conv_0): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose3d(512, 512, kernel_size=(6, 1, 1), stride=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_1): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (p_conv_2): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_3): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (p_conv_4): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_5): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (p_conv_6): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose3d(512, 512, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_7): Sequential(
#     (0): Sequential(
#       (0): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (p_conv_8): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose3d(512, 256, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down_conv_9): Sequential(
#     (0): Sequential(
#       (0): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
net_g(inputs.permute(0, 2, 1, 3, 4).float()).shape
# Out:
# torch.Size([12, 3, 6, 64, 64])

# %% [markdown]
# # Discriminator

# %%
class FrameDiscriminator(nn.Module):
    def __init__(self, input_shape: int, input_dim, hidden_units: int, output_unit: int, blocks: int, increment: int = 1):
        super().__init__()
        self.input_layer = nn.Sequential(
          nn.Conv2d(in_channels=input_shape, out_channels=hidden_units, kernel_size=4, stride=2),
          nn.LeakyReLU(0.2)
        )

        self.input_dim = input_dim

        # Create sequential blocks
        self.blocks = nn.ModuleList()
        for i in range(blocks):
          # Calculate input and output channels for each block
          out_channels = hidden_units * (2 ** (increment + i))
          in_channels = hidden_units if i == 0 else hidden_units * (2 ** (increment + i - 1))
          self.blocks.append(nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=4, stride=2),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2)
          ))

        self.blocks.append(nn.Sequential(
          nn.Conv2d(in_channels=hidden_units * (2 ** (increment + blocks - 1)), out_channels=output_unit, kernel_size=4, stride=1),
        ))

        a = self.calculate_encoder_output_size()

        # Classfier
        self.classifier = nn.Sequential(
          nn.Flatten(),
          nn.Linear(in_features=a,out_features=1),
          nn.Sigmoid()
        )

    def calculate_encoder_output_size(self):
      input_dim = self.input_dim

      x = torch.rand((1, 3, input_dim[0], input_dim[1]))

      x = self.input_layer(x)
      for block in self.blocks:
        x = block(x)

      print(x.shape)
      return x.shape[-1] * x.shape[-2] * x.shape[-3]

    def forward(self, x):
        x = self.input_layer(x)
        for block in self.blocks:
          x = block(x)

        x = self.classifier(x)
        return x

# Example usage
frame_model = FrameDiscriminator(input_shape=3, input_dim=(256, 256), hidden_units=64, output_unit=1, blocks=2)

frame_model
# Out:
# torch.Size([1, 1, 27, 27])
# FrameDiscriminator(
#   (input_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (blocks): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (2): Sequential(
#       (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1))
#     )
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=729, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )

# %%
batch_input = torch.rand(12, 3, 256, 256)
frame_model(batch_input).shape
# Out:
# torch.Size([12, 1])

# %%
class SequenceDescriminator(nn.Module):
    def __init__(self, input_shape: int, input_dim, hidden_units: int, output_unit: int, blocks: int, increment: int = 1):
        super().__init__()
        self.input_layer = nn.Sequential(
            nn.Conv3d(in_channels=input_shape, out_channels=hidden_units, kernel_size=3, stride=1,padding=1),
            nn.LeakyReLU(0.2)
        )
        
        # Create sequential blocks
        self.blocks = nn.ModuleList()
        for i in range(blocks):
            # Calculate input and output channels for each block
            out_channels = hidden_units * (2 ** (increment + i))
            in_channels = hidden_units if i == 0 else hidden_units * (2 ** (increment + i - 1))
            self.blocks.append(nn.Sequential(
                nn.Conv3d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1,padding=1),
                nn.BatchNorm3d(out_channels),
                nn.LeakyReLU(0.2)
            ))
        self.output_conv3d = nn.Sequential(
                nn.Conv3d(in_channels=hidden_units * (2 ** (increment + blocks - 1)), out_channels=output_unit, kernel_size=3, stride=1,padding=0)
        )
        self.input_dim = input_dim
        a = self.calculate_encoder_output_size()
        
        # Output layer
        self.output_layer = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=a,out_features=1),
            nn.Sigmoid()
        )
    def calculate_encoder_output_size(self):
        input_dim = self.input_dim

        x = torch.rand((1, 3,5, input_dim[0], input_dim[1]))

        x = self.input_layer(x)
        for block in self.blocks:
            x = block(x)
        x =self.output_conv3d(x)
        print(x.shape)
        return x.shape[-1] * x.shape[-2] * x.shape[-3]
        
    def forward(self, x):
        x = self.input_layer(x)
        # print('After input layer:', x.shape)
        for block in self.blocks:
            x = block(x)
            # print('After block:', x.shape)
        x = self.output_conv3d(x)
        x = self.output_layer(x)
        # print('After output layer:', x.shape)
        return x

Sequence_Model = SequenceDescriminator(input_shape=3,input_dim=(256,256),hidden_units=64,output_unit=1,blocks=3)
# Out:
# torch.Size([1, 1, 3, 254, 254])

# %%
batch_input = torch.rand(1,3,5, 256, 256)
Sequence_Model(batch_input).shape
# Out:
# torch.Size([1, 1])

# %% [markdown]
# # Structural Similarity Index (SSIM)

# %%
from skimage.metrics import structural_similarity as ssim

# %%
slice_ = inputs[5]
consistency = []

curr_frame = slice_[0].permute(1, 2, 0).numpy()
next_frame = slice_[1].permute(1, 2, 0).numpy()

ax = plt.subplot(1, 6, 1)
ax.imshow(curr_frame)
plt.axis('off')

for i in range(1, 5):
  curr_frame = slice_[i].permute(1, 2, 0).numpy()
  next_frame = slice_[i+1].permute(1, 2, 0).numpy()
  consistency.append(ssim(curr_frame, next_frame, data_range=next_frame.max() - next_frame.min(), win_size=3))
  ax = plt.subplot(1, 6, i+1)
  ax.imshow(curr_frame)
  ax.set_title(round(consistency[-1], 2))
  ax.axis('off')

ax = plt.subplot(1, 6, 6)
ax.imshow(next_frame)
ax.set_title(round(consistency[-1], 2))
ax.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
import numpy as np

class ConsistencyLoss(nn.Module):
  def __init__(self):
    super(ConsistencyLoss, self).__init__()

  def forward(self, frame_sequence):

    consistency = []

    for i in range(5):
      curr_frame = slice_[i].permute(1, 2, 0).numpy()
      next_frame = slice_[i+1].permute(1, 2, 0).numpy()
      consistency.append(ssim(curr_frame, next_frame, data_range=next_frame.max() - next_frame.min(), win_size=3))

    # needs to be changed to a torch method
    return np.mean(consistency)

# %%
ConsistencyLoss()(slice_)
# Out:
# 0.9056135718676529
